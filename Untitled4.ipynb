# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Sample_-_Superstore[1].csv', encoding='latin1')
df.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 2       3  CA-2016-138688  6/12/2016   6/16/2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(3)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# Name: Sales, dtype: float64

# %%
df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(3)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     7753.0390
# Hewlett Packard LaserJet 3310 Copier                                            6983.8836
# Name: Profit, dtype: float64

# %%
df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).tail(3)
# Out:
# Product Name
# Cubify CubeX 3D Printer Triple Head Print   -3839.9904
# Lexmark MX611dhe Monochrome Laser Printer   -4589.9730
# Cubify CubeX 3D Printer Double Head Print   -8879.9704
# Name: Profit, dtype: float64

# %%
df.groupby('Region')['Discount'].mean()
# Out:
# Region
# Central    0.240353
# East       0.145365
# South      0.147253
# West       0.109335
# Name: Discount, dtype: float64

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).head(3)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Name: Profit, dtype: float64

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df.groupby(df['Order Date'].dt.month)['Sales'].sum()
# Out:
# Order Date
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %%
df.groupby(df['Order Date'].dt.month)['Profit'].sum
# Out:
# <bound method GroupBy.sum of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7ceebcf17a40>>

# %%
(df.groupby('Category')['Profit'].sum() / df.groupby('Category')['Sales'].sum()) * 100
# Out:
# Category
# Furniture           2.486695
# Office Supplies    17.035158
# Technology         17.395712
# dtype: float64

# %%
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(3)
# Out:
# Customer Name
# Sean Miller     25043.050
# Tamara Chand    19052.218
# Raymond Buch    15117.339
# Name: Sales, dtype: float64

# %%
df.groupby('Customer Name')['Profit'].sum().sort_values(ascending=False).head(3)
# Out:
# Customer Name
# Tamara Chand    8981.3239
# Raymond Buch    6976.0959
# Sanjit Chand    5757.4119
# Name: Profit, dtype: float64

# %%
df[['Sales','Profit','Discount']].corr()
# Out:
#              Sales    Profit  Discount
# Sales     1.000000  0.479064 -0.028190
# Profit    0.479064  1.000000 -0.219487
# Discount -0.028190 -0.219487  1.000000

# %%
df.groupby( 'Product Name')['Sales'].sum().sort_values(ascending=False).head(3)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# Name: Sales, dtype: float64

# %%
region_sales=df.groupby('Region')['Sales'].sum()
(region_sales/region_sales.sum())*100
# Out:
# Region
# Central    21.819594
# East       29.548188
# South      17.052140
# West       31.580078
# Name: Sales, dtype: float64

# %%
margin=(df.groupby('Category')['Profit'].sum()
/df.groupby('Category')['Sales'].sum())*100
margin.sort_values(ascending=False)
# Out:
# Category
# Technology         17.395712
# Office Supplies    17.035158
# Furniture           2.486695
# dtype: float64

# %%
df[['Discount','Profit']].corr()
# Out:
#           Discount    Profit
# Discount  1.000000 -0.219487
# Profit   -0.219487  1.000000
